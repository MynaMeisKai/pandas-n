# %%
import pandas as pd

df = pd.DataFrame([[12,43,55],[44,44,44],[21,64,78],[9,45,33]],columns=["A","B","C"],index=["a","b","c","d"])

# %%
#Head 
df.head(1)

# %%
#Tail 
df.tail()
# Out:
#     A   B   C
# a  12  43  55
# b  44  44  44
# c  21  64  78
# d   9  45  33

# %%
#Describe

df.describe()

# %%
#Unique
df["B"].unique()

# %%
#num of unique 

df["B"].nunique()

# %%
#Index

df.index.to_list()

# %%
#info - information of DataFrame

df.info()

# %%
#shape & size

# df.shape
# df.size
# Out:
# 12
